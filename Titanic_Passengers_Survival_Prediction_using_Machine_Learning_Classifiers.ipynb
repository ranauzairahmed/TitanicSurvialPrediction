# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('/content/train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.barplot(train, x='Sex', y='Survived')
plt.show()

# %%
sns.countplot(train, x='Sex', hue='Survived')
plt.show()

# %%
grouped_by_gender = train.groupby(['Sex', 'Survived'])
grouped_by_gender = grouped_by_gender.size().unstack()
grouped_by_gender
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
total_survived = grouped_by_gender[1].sum()

# %%
females_survived = grouped_by_gender[1]['female']
males_survived = grouped_by_gender[1]['male']
print(f"Females survived: {females_survived / total_survived * 100: .2f}", )
print(f"Males survived: {males_survived / total_survived * 100: .2f}", )
# Out:
# Females survived:  68.13
# Males survived:  31.87

# %%
grouped_by_pclass = train.groupby(['Pclass', 'Survived'])
grouped_by_pclass = grouped_by_pclass.size().unstack()
grouped_by_pclass
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pclass1_survived = grouped_by_pclass[1][1]
pclass2_survived = grouped_by_pclass[1][2]
pclass3_survived = grouped_by_pclass[1][3]
print(f"Pclass 1 survived: {pclass1_survived / total_survived * 100: .2f}", )
print(f"Pclass 2 survived: {pclass2_survived / total_survived * 100: .2f}", )
print(f"Pclass 3 survived: {pclass3_survived / total_survived * 100: .2f}", )
# Out:
# Pclass 1 survived:  39.77
# Pclass 2 survived:  25.44
# Pclass 3 survived:  34.80

# %%
sns.barplot(train, x='Pclass', y='Survived')
plt.show()

# %%
sns.barplot(train, x='SibSp', y='Survived')
plt.show()

# %%
grouped_by_SibSp = train.groupby(['SibSp', 'Survived'])
grouped_by_SibSp = grouped_by_SibSp.size().unstack()
grouped_by_SibSp
# Out:
# Survived      0      1
# SibSp
# 0         398.0  210.0
# 1          97.0  112.0
# 2          15.0   13.0
# 3          12.0    4.0
# 4          15.0    3.0
# 5           5.0    NaN
# 8           7.0    NaN

# %%
SibSp0_survived = grouped_by_SibSp[1][0]
SibSp1_survived = grouped_by_SibSp[1][1]
SibSp2_survived = grouped_by_SibSp[1][2]
SibSp3_survived = grouped_by_SibSp[1][3]
SibSp4_survived = grouped_by_SibSp[1][4]
SibSp5_survived = grouped_by_SibSp[1][5]
SibSp8_survived = grouped_by_SibSp[1][8]

print(f"SibSp 0 survived: {SibSp0_survived / total_survived * 100: .2f}", )
print(f"SibSp 1 survived: {SibSp1_survived / total_survived * 100: .2f}", )
print(f"SibSp 2 survived: {SibSp2_survived / total_survived * 100: .2f}", )
print(f"SibSp 3 survived: {SibSp3_survived / total_survived * 100: .2f}", )
print(f"SibSp 4 survived: {SibSp4_survived / total_survived * 100: .2f}", )
print(f"SibSp 5 survived: {SibSp5_survived / total_survived * 100: .2f}", )
print(f"SibSp 8 survived: {SibSp8_survived / total_survived * 100: .2f}", )
# Out:
# SibSp 0 survived:  61.40
# SibSp 1 survived:  32.75
# SibSp 2 survived:  3.80
# SibSp 3 survived:  1.17
# SibSp 4 survived:  0.88
# SibSp 5 survived:  nan
# SibSp 8 survived:  nan

# %%
train.drop(['Cabin', 'Ticket', 'Name', 'Fare', 'PassengerId'], axis=1, inplace=True)

# %%
train[train['Embarked'] =='S'].shape[0]
# Out:
# 644

# %%
train[train['Embarked'] =='C'].shape[0]
# Out:
# 168

# %%
train[train['Embarked'] =='Q'].shape[0]
# Out:
# 77

# %%
train['Embarked'].fillna('S', inplace=True)
# Out:
# <ipython-input-43-4f2a70d3b6f3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Embarked'].fillna('S', inplace=True)

# %%
embarked_mapping = {'S':1, 'C':2, 'Q': 3}

# %%
train['Embarked'] = train['Embarked'].map(embarked_mapping)

# %%
train.Age = train.Age.fillna(train.Age.mean())

# %%
gender_mapping = {'male': 0, 'female': 1}
train['Sex'] = train['Sex'].map(gender_mapping)

# %%
from sklearn.model_selection  import train_test_split

# %%
predictors = train.drop(['Survived'], axis=1)
target = train['Survived']

X_train, X_val, y_train, y_val = train_test_split(predictors, target, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC

# %%
log_reg = LogisticRegression()
NB = GaussianNB()
decision_tree = DecisionTreeClassifier()
knn = KNeighborsClassifier(n_neighbors=5)
linear_svc = LinearSVC()
svm = SVC(probability=True)

# %%
log_reg.fit(X_train, y_train)
NB.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
knn.fit(X_train, y_train)
linear_svc.fit(X_train, y_train)
svm.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
from sklearn.metrics import roc_curve, auc, accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
models= [("Logistic Regression", log_reg), ("Naive Bayes", NB), ("Decision Tree", decision_tree), ("KNN", knn), ("Linear SVM", linear_svc), ("SVM", svm)]
model_accuracies = []

# %%
for name, model in models:
  try:
    y_prob = model.predict_proba(X_val)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_val, y_prob)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f"ROC curve(area = {roc_auc: 2f}) for {name}")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel("False Positive Rate")
    plt.xlabel("True Positive Rate")
    plt.title("Receiver Operating Characteristics (ROC) Curve")
    plt.legend()
    plt.show()
  except:
    pass

  y_pred = model.predict(X_val)
  accuracy = accuracy_score(y_val, y_pred)
  print(f"{name} - Accuracy: {accuracy: .2f}, AUC: {roc_auc: .2f}")
  model_accuracies.append((name, accuracy))
  print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))
  print("Classification Report:\n", classification_report(y_val, y_pred))
# Out:
# Logistic Regression - Accuracy:  0.82, AUC:  0.86
# Confusion Matrix:
#  [[92 18]
#  [15 54]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       110
#            1       0.75      0.78      0.77        69
#
#     accuracy                           0.82       179
#    macro avg       0.80      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179
# Naive Bayes - Accuracy:  0.80, AUC:  0.85
# Confusion Matrix:
#  [[90 20]
#  [16 53]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       110
#            1       0.73      0.77      0.75        69
#
#     accuracy                           0.80       179
#    macro avg       0.79      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179
# Decision Tree - Accuracy:  0.80, AUC:  0.78
# Confusion Matrix:
#  [[96 14]
# ...

# %%
import seaborn as sns

# %%
names = [name for name, _ in model_accuracies]
accuracies = [acc for _, acc in model_accuracies]
for name, accuracy in zip(names, accuracies):
  print(f"{name}: {accuracy}")
# Out:
# Logistic Regression: 0.8156424581005587
# Naive Bayes: 0.7988826815642458
# Decision Tree: 0.7988826815642458
# KNN: 0.776536312849162
# Linear SVM: 0.7988826815642458
# SVM: 0.6424581005586593

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=names, y=accuracies)
plt.show()
